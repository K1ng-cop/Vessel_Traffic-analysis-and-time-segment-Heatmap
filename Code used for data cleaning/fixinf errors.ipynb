# %%
import pandas as pd

# %%
file_path = 'RSA_COASTDATA 6.csv'

# %%
df = pd.read_csv(file_path, delimiter=',', header=None, low_memory=False)

# %%
headers = ['UTCPortTime', 'Port', 'SourceMMSI', 'MessageID', 'RepeatIndicator', 
           'NavigationalStatus', 'RateOfTurn', 'SpeedOverGround', 'PositionAccuracy', 
           'Latitude', 'Longitude', 'CourseOverGround', 'Heading']

df.columns = headers

# %%
df.head()
# Out:
#            UTCPortTime  Port  SourceMMSI  MessageID  RepeatIndicator  \
# 0          UTCPortTime  Port  SourceMMSI  MessageID  RepeatIndicator
# 1  2024-02-22 00:00:01     1   271002721          1     Not repeated
# 2  2024-02-22 00:00:07     1   563140400          1     Not repeated
# 3  2024-02-22 00:00:17     1   636021527          1     Not repeated
# 4  2024-02-22 00:15:38     1   636016212          1     Not repeated
#
#            NavigationalStatus  \
# 0          NavigationalStatus
# 1  0 - under way using engine
# 2  0 - under way using engine
# 3  0 - under way using engine
# 4  0 - under way using engine
#
#                                           RateOfTurn  SpeedOverGround  \
# 0                                         RateOfTurn  SpeedOverGround
# 1                             Turning Right 000°/min       11.7 knots
# 2                             Turning Right 011°/min       11.1 knots
# 3  Turning Right at more than 005°/30s (No TI ava...        8.6 knots
# ...
